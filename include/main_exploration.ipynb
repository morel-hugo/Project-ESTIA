# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('../datas/df_final.csv')
df = df.set_index("TIME")

# %%
df.head()
# Out:
#      INDICATOR_approvisionnement SUBJECT_approvisionnement  \
# TIME
# 1980               PRYENRGSUPPLY                       TOT
# 1981               PRYENRGSUPPLY                       TOT
# 1982               PRYENRGSUPPLY                       TOT
# 1983               PRYENRGSUPPLY                       TOT
# 1984               PRYENRGSUPPLY                       TOT
#
#      MEASURE_approvisionnement  Value_approvisionnement  \
# TIME
# 1980               TOE_1000USD                    0.191
# 1981               TOE_1000USD                    0.186
# 1982               TOE_1000USD                    0.198
# 1983               TOE_1000USD                    0.182
# 1984               TOE_1000USD                    0.178
#
#      Flag Codes_approvisionnement INDICATOR_production SUBJECT_production  \
# TIME
# 1980                          NaN              OILPROD                TOT
# 1981                          NaN              OILPROD                TOT
# ...

# %%
Value_index = ['Value_approvisionnement','Value_production','Value_prix','Value_renouvelable']
sns.pairplot(df[Value_index])
# Out:
# C:\Users\HugoMOREL\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\HugoMOREL\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.lineplot(data=df['Value_approvisionnement'],palette='tab10',linewidth=2.5)

# %%
df['Value_approvisionnement'].plot(figsize=(16,4),label='Value_production')

# %%
sns.distplot(df['Value_approvisionnement'],color='green',bins=100)
# Out:
# C:\Users\HugoMOREL\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\HugoMOREL\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
sns.distplot(df['Value_production'],color='green',bins=100)

# %%
sns.distplot(df['Value_prix'],color='green',bins=100)

# %%
sns.distplot(df['Value_renouvelable'],color='green',bins=100)

# %%
df['Value_prix'].plot(figsize=(16,4),label='Value_production')

# %%
df['Value_renouvelable'].plot(figsize=(16,6),label='Value_renouvelable')

# %%
df[]
