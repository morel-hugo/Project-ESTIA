# %%
import pandas as pd
import numpy as np
import matplotlib as pls
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('../datas/df_final.csv')

# %%
df.head()
# Out:
#    TIME INDICATOR_approvisionnement SUBJECT_approvisionnement  \
# 0  1980               PRYENRGSUPPLY                       TOT
# 1  1981               PRYENRGSUPPLY                       TOT
# 2  1982               PRYENRGSUPPLY                       TOT
# 3  1983               PRYENRGSUPPLY                       TOT
# 4  1984               PRYENRGSUPPLY                       TOT
#
#   MEASURE_approvisionnement  Value_approvisionnement  \
# 0               TOE_1000USD                    0.191
# 1               TOE_1000USD                    0.186
# 2               TOE_1000USD                    0.198
# 3               TOE_1000USD                    0.182
# 4               TOE_1000USD                    0.178
#
#   Flag Codes_approvisionnement INDICATOR_production SUBJECT_production  \
# 0                          NaN              OILPROD                TOT
# 1                          NaN              OILPROD                TOT
# 2                          NaN              OILPROD                TOT
# 3                          NaN              OILPROD                TOT
# 4                          NaN              OILPROD                TOT
#
#   MEASURE_production  Value_production Flag Codes_production LOCATION  \
# 0               KTOE         19471.877                   NaN      AUS
# 1               KTOE         19007.475                   NaN      AUS
# 2               KTOE         18706.129                   NaN      AUS
# 3               KTOE         18220.054                   NaN      AUS
# 4               KTOE         22148.899                   NaN      AUS
#
#   FREQUENCY  Value_prix  Value_renouvelable
# 0         A       31.81            4745.682
# 1         A       35.88            5063.213
# 2         A       35.42            5173.465
# 3         A       30.88            5006.549
# 4         A       29.19            4912.525

# %%
Value_index = ['Value_approvisionnement','Value_production','Value_prix','Value_renouvelable']
sns.pairplot(df[Value_index])

# %%
sns.distplot(df['Value_approvisionnement'],color='green',bins=100)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
sns.distplot(df['Value_production'],color='green',bins=100)

# %%
sns.distplot(df['Value_prix'],color='green',bins=100)

# %%
sns.distplot(df['Value_renouvelable'],color='green',bins=100)
